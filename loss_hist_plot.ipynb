# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
f = np.load('loss_hist/loss_female_epo200.npy')
m = np.load('loss_hist/loss_male_epo200.npy')
f_s = np.load('loss_hist/loss_female_sche_sampling_epo164.npy')

# %%
fig = plt.figure(1)
ax = fig.add_subplot(111)   
ax.plot(f,label='female',c='r')
ax.plot(m,label='male')
ax.plot(f_s,label='female_schedule_sampling')
ax.legend()
fig.savefig('loss.png')
